# %%
from src.data_utility.utilities import get_project_directory_path
import os
project_dir = get_project_directory_path()

# %%
from IPython.core.display import HTML, Image
from IPython.display import display
from src.doctable import Doctable

# %% [markdown]
# # test image

# %%
img_path = os.path.join(project_dir, 'data/images/detection_img2.jpg')

# %%
display(Image(filename=img_path))

# %%
doctable = Doctable()
pages = doctable.table_extraction(img_path)
# Out:
# Ultralytics YOLOv8.0.43  Python-3.9.13 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# 0: 640x480 1 bordered, 76.5ms
# Speed: 1.0ms preprocess, 76.5ms inference, 612.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
for page in pages:
    for table in page.tables:
        display(HTML(table.recognition_results["html"]))
# Out:
# <html><body><table><thead><tr><td>N.E.T Corridor(LRT)</td><td></td><td> Control Corridor (Non-LRT)</td><td>City of Nottingham</td></tr></thead><tbody><tr><td colspan="4">Average Price Paid ()</td></tr><tr><td>2001</td><td>62380</td><td>73509</td><td>68026</td></tr><tr><td>2011</td><td>102677</td><td>128366</td><td>118018</td></tr><tr><td> Change</td><td>64.60%</td><td>74.63%</td><td>73.07%</td></tr><tr><td colspan="4">Rate of Property Turnover (transactions per annum)</td></tr><tr><td>2001</td><td>1,175</td><td>445</td><td>5,627</td></tr><tr><td>2011</td><td>441</td><td>263</td><td>2,637</td></tr><tr><td>%6 Change</td><td>62%</td><td>41%</td><td>53%</td></tr></tbody></table></body></html>

# %% [markdown]
# # test pdf

# %%
pdf_path = os.path.join(project_dir, 'data/pdf/test_pdf.pdf')

# %%
doctable = Doctable()
pages = doctable.table_extraction(pdf_path)
# Out:
# Ultralytics YOLOv8.0.43  Python-3.9.13 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# 0: 640x480 1 bordered, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 2 bordereds, 3 borderlesss, 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 1 bordered, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 1 bordered, 1 borderless, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 2 borderlesss, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 1 borderless, 99.2ms
# ...

# %%
for page in pages:
    for table in page.tables:
        display(HTML(table.recognition_results["html"]))
# Out:
# <html><body><table><thead><tr><td rowspan="2">Design</td><td rowspan="2">Bahay. VHDL lines</td><td colspan="3">Traditional behavioral synthesis</td><td colspan="3">New bahavioral synthesis</td></tr><tr><td>VHDL RTL lines</td><td>Gates</td><td>Critical path (ns)</td><td>VHDL RTL lines</td><td>Gates</td><td>Oritical path (ns)</td></tr></thead><tbody><tr><td>HME</td><td>290</td><td>6021</td><td>7850</td><td>11.19</td><td>538</td><td>4200</td><td>8.49</td></tr><tr><td>Sched</td><td>781</td><td>4176</td><td>5060</td><td>19.57</td><td>1476</td><td>4350</td><td>13.82</td></tr><tr><td>Sendar</td><td>621</td><td>3267</td><td>3930</td><td>18.31</td><td>1289</td><td>3840</td><td>16.46</td></tr><tr><td>Abrsa</td><td>425</td><td>3765</td><td>3220</td><td>18.76</td><td>952</td><td>3440</td><td>14.35</td></tr><tr><td>T.unit</td><td>115</td><td>985</td><td>730</td><td>16.14</td><td>209</td><td>800</td><td>13.25</td></tr></tbody></table></body></html>
# ...
